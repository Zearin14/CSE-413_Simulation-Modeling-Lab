# %% [markdown]
# 1

# %%
import numpy as np
scalar=3.7
arr=np.array([7,14,5.8,2.1,6,77])
print("Scalar =", scalar)
print("Array =", arr)
print("Addition:")
print(arr + scalar)
print("Subtraction:")
print(arr - scalar)
print("Multiplication:")
print(arr * scalar)
print("Division:")
print(arr / scalar)
sin_values=np.sin(arr)
cos_values=np.cos(arr)
tan_values=np.tan(arr)
asin_values=np.arcsin(np.clip(arr/np.max(arr),-1,1))
acos_values=np.arccos(np.clip(arr/np.max(arr),-1,1))
atan_values=np.arctan(arr)
exp_values=np.exp(arr)
log_values=np.log(arr)
abs_values=np.abs(arr)
sqrt_values=np.sqrt(arr)
rem_values=np.remainder(arr,2)
round_values=np.round(arr)
floor_values=np.floor(arr)
ceil_values=np.ceil(arr)
print("sin:",sin_values)
print("cos:",cos_values)
print("tan:",tan_values)
print("asin:",asin_values)
print("acos:",acos_values)
print("atan:",atan_values)
print("exp:",exp_values)
print("log:",log_values)
print("abs:",abs_values)
print("sqrt:",sqrt_values)
print("rem:",rem_values)
print("round:",round_values)
print("floor:",floor_values)
print("ceil:",ceil_values)
# Out:
# Scalar = 3.7
# Array = [ 7.  14.   5.8  2.1  6.  77. ]
# Addition:
# [10.7 17.7  9.5  5.8  9.7 80.7]
# Subtraction:
# [ 3.3 10.3  2.1 -1.6  2.3 73.3]
# Multiplication:
# [ 25.9   51.8   21.46   7.77  22.2  284.9 ]
# Division:
# [ 1.89189189  3.78378378  1.56756757  0.56756757  1.62162162 20.81081081]
# sin: [ 0.6569866   0.99060736 -0.46460218  0.86320937 -0.2794155   0.99952016]
# cos: [ 0.75390225  0.13673722  0.88551952 -0.5048461   0.96017029 -0.03097503]
# tan: [  0.87144798   7.24460662  -0.52466622  -1.70984654  -0.29100619
#  -32.26857578]
# asin: [0.09103478 0.18283514 0.07539609 0.02727611 0.07800115 1.57079633]
# acos: [1.47976155 1.38796119 1.49540024 1.54352022 1.49279518 0.        ]
# atan: [1.42889927 1.49948886 1.40006112 1.12637712 1.40564765 1.55781004]
# exp: [1.09663316e+03 1.20260428e+06 3.30299560e+02 8.16616991e+00
#  4.03428793e+02 2.75851345e+33]
# log: [1.94591015 2.63905733 1.75785792 0.74193734 1.79175947 4.34380542]
# abs: [ 7.  14.   5.8  2.1  6.  77. ]
# sqrt: [2.64575131 3.74165739 2.40831892 1.44913767 2.44948974 8.77496439]
# rem: [1.  0.  1.8 0.1 0.  1. ]
# round: [ 7. 14.  6.  2.  6. 77.]
# floor: [ 7. 14.  5.  2.  6. 77.]
# ceil: [ 7. 14.  6.  3.  6. 77.]

# %% [markdown]
# 2

# %%
import numpy as np
from sympy import Matrix
matrix=np.array([[66,44],[67,45]])
sin_value=np.sin(matrix)
cos_values=np.cos(matrix)
tan_values=np.tan(matrix)
asin_values=np.arcsin(np.clip(arr/np.max(arr),-1,1))
acos_values=np.arccos(np.clip(arr/np.max(arr),-1,1))
atan_values=np.arctan(arr)
exp_values=np.exp(arr)
log_values=np.log(arr)
abs_values=np.abs(arr)
sqrt_values=np.sqrt(arr)
rem_values=np.remainder(arr,2)
round_values=np.round(arr)
floor_values=np.floor(arr)
ceil_values=np.ceil(arr)
print("sin:",sin_values)
print("cos:",cos_values)
print("tan:",tan_values)
print("asin:",asin_values)
print("acos:",acos_values)
print("atan:",atan_values)
print("exp:",exp_values)
print("log:",log_values)
print("abs:",abs_values)
print("sqrt:",sqrt_values)
print("rem:",rem_values)
print("round:",round_values)
print("floor:",floor_values)
print("ceil:",ceil_values)
# Out:
# sin: [ 0.6569866   0.99060736 -0.46460218  0.86320937 -0.2794155   0.99952016]
# cos: [[-0.99964746  0.99984331]
#  [-0.5177698   0.52532199]]
# tan: [[0.02656052 0.0177047 ]
#  [1.65231726 1.61977519]]
# asin: [0.09103478 0.18283514 0.07539609 0.02727611 0.07800115 1.57079633]
# acos: [1.47976155 1.38796119 1.49540024 1.54352022 1.49279518 0.        ]
# atan: [1.42889927 1.49948886 1.40006112 1.12637712 1.40564765 1.55781004]
# exp: [1.09663316e+03 1.20260428e+06 3.30299560e+02 8.16616991e+00
#  4.03428793e+02 2.75851345e+33]
# log: [1.94591015 2.63905733 1.75785792 0.74193734 1.79175947 4.34380542]
# abs: [ 7.  14.   5.8  2.1  6.  77. ]
# sqrt: [2.64575131 3.74165739 2.40831892 1.44913767 2.44948974 8.77496439]
# rem: [1.  0.  1.8 0.1 0.  1. ]
# round: [ 7. 14.  6.  2.  6. 77.]
# floor: [ 7. 14.  5.  2.  6. 77.]
# ceil: [ 7. 14.  6.  3.  6. 77.]

# %% [markdown]
# 3

# %%
import numpy as np
from sympy import Matrix
matrix=np.array([[66,44],[67,45],[68,46]])
sin_value=np.sin(matrix)
cos_values=np.cos(matrix)
tan_values=np.tan(matrix)
asin_values=np.arcsin(np.clip(arr/np.max(arr),-1,1))
acos_values=np.arccos(np.clip(arr/np.max(arr),-1,1))
atan_values=np.arctan(arr)
exp_values=np.exp(arr)
log_values=np.log(arr)
abs_values=np.abs(arr)
sqrt_values=np.sqrt(arr)
rem_values=np.remainder(arr,2)
round_values=np.round(arr)
floor_values=np.floor(arr)
ceil_values=np.ceil(arr)
print("sin:",sin_values)
print("cos:",cos_values)
print("tan:",tan_values)
print("asin:",asin_values)
print("acos:",acos_values)
print("atan:",atan_values)
print("exp:",exp_values)
print("log:",log_values)
print("abs:",abs_values)
print("sqrt:",sqrt_values)
print("rem:",rem_values)
print("round:",round_values)
print("floor:",floor_values)
print("ceil:",ceil_values)
# Out:
# sin: [ 0.6569866   0.99060736 -0.46460218  0.86320937 -0.2794155   0.99952016]
# cos: [[-0.99964746  0.99984331]
#  [-0.5177698   0.52532199]
#  [ 0.44014302 -0.43217794]]
# tan: [[ 0.02656052  0.0177047 ]
#  [ 1.65231726  1.61977519]
#  [-2.0400816  -2.08661353]]
# asin: [0.09103478 0.18283514 0.07539609 0.02727611 0.07800115 1.57079633]
# acos: [1.47976155 1.38796119 1.49540024 1.54352022 1.49279518 0.        ]
# atan: [1.42889927 1.49948886 1.40006112 1.12637712 1.40564765 1.55781004]
# exp: [1.09663316e+03 1.20260428e+06 3.30299560e+02 8.16616991e+00
#  4.03428793e+02 2.75851345e+33]
# log: [1.94591015 2.63905733 1.75785792 0.74193734 1.79175947 4.34380542]
# abs: [ 7.  14.   5.8  2.1  6.  77. ]
# sqrt: [2.64575131 3.74165739 2.40831892 1.44913767 2.44948974 8.77496439]
# rem: [1.  0.  1.8 0.1 0.  1. ]
# round: [ 7. 14.  6.  2.  6. 77.]
# floor: [ 7. 14.  5.  2.  6. 77.]
# ceil: [ 7. 14.  6.  3.  6. 77.]

# %% [markdown]
# 4

# %%
import numpy as np
vec=np.array([8,4,7,2,9,46,8])
max_value=np.max(vec)
max_index=np.argmax(vec)
min_values=np.min(vec)
min_index=np.argmin(vec)
vec_length=len(vec)
sorted_vec=np.sort(vec)
sum_values=np.sum(vec)
prod_values=np.prod(vec)
median_values=np.median(vec)
mean_value=np.mean(vec)
std_dev=np.std(vec)
print("Max value:", max_value, "at index", max_index)
print("Min value:", min_values, "at index", min_index)
print("Length of vector:", vec_length)
print("Sorted vector:", sorted_vec)
print("Sum of elements:", sum_values)
print("Product of elements:", prod_values)
print("Median value:", median_values)
print("Mean value:", mean_value)
print("Standard deviation:", std_dev)
# Out:
# Max value: 46 at index 5
# Min value: 2 at index 3
# Length of vector: 7
# Sorted vector: [ 2  4  7  8  8  9 46]
# Sum of elements: 84
# Product of elements: 1483776
# Median value: 8.0
# Mean value: 12.0
# Standard deviation: 14.071247279470288

# %% [markdown]
# 5

# %%
import numpy as np
matrix = np.array([[6.6,4.4,5.5],[6.7,4.5,5.6]])
vec = matrix.flatten()
max_value = np.max(vec)
max_index = np.argmax(vec)
min_value = np.min(vec)
min_index = np.argmin(vec)
vec_length = np.linalg.norm(vec)
sorted_matrix = np.sort(matrix, axis=1)
sorted_vec = np.sort(vec)
sum_values = np.sum(vec)
prod_values = np.prod(vec)
median_values = np.median(matrix)
mean_value = np.mean(matrix)
std_dev = np.std(matrix)
print("Max value:", max_value, "at index", max_index)
print("Min value:", min_value, "at index", min_index)
print("length of vector:", vec_length)
print("Row-wise sorted matrix:")
print(sorted_matrix)
print("Sorted vector:")
print(sorted_vec)
print("Sum:", sum_values)
print("Product:", prod_values)
print("Median:", median_values)
print("Mean:", mean_value)
print("Standard deviation:", std_dev)
# Out:
# Max value: 6.7 at index 3
# Min value: 4.4 at index 1
# length of vector: 13.772073191789245
# Row-wise sorted matrix:
# [[4.4 5.5 6.6]
#  [4.5 5.6 6.7]]
# Sorted vector:
# [4.4 4.5 5.5 5.6 6.6 6.7]
# Sum: 33.3
# Product: 26967.124799999998
# Median: 5.55
# Mean: 5.55
# Standard deviation: 0.899536917900909

# %%
import numpy as np

matrix = np.random.uniform(1, 100, (9, 2))

print("Random Matrix:")
print(matrix)
# Out:
# Random Matrix:
# [[43.06897588 24.03117075]
#  [18.68417915 25.68295026]
#  [53.03248451 18.26962375]
#  [74.28789689 99.35978532]
#  [ 6.85565036 84.19285788]
#  [13.86855703 44.59845438]
#  [69.70797743 85.52042624]
#  [82.84251142 11.65416346]
#  [46.65749781 21.87560484]]

# %%
import matplotlib.pyplot as plt
import numpy as np

matrix = np.array([[66, 44],
                   [67, 45],
                   [68, 46]])

plt.imshow(matrix, cmap="viridis")
plt.colorbar()
plt.title("3×2 Matrix Heatmap")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

matrix = np.array([[66, 44],
                   [67, 45],
                   [68, 46]])

sns.heatmap(matrix, annot=True, cmap="viridis")

plt.title("3×2 Matrix Heatmap")
plt.show()
